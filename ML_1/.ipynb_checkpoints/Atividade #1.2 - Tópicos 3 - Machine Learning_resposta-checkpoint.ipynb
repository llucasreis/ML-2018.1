# %% [markdown]
# # Teste 1.2 - Problema de Regressão
# ## Início: 08/03/2018 16h20 e Término: 08/03/2018 23h59min
#
# O objetivo deste primeiro teste da disciplina Tópicos Especiais em Engenharia de Computação III é praticar os conceitos de Machine Learning vistos até o momento, em especial aqueles relativos ao processo de Aprendizagem de Máquina.
#
# Vamos trabalhar agora com um problema de regressão. Utilizaremos o dataset visto em sala **AUTO MPG**
#
# Consulte o link: https://archive.ics.uci.edu/ml/datasets/Auto+MPG
#
# Para facilitar esta tarefa, um pouco de pré-processamento já foi feito no dataset, disponível junto aos arquivos da avaliação intitulado 'autompg.csv'. Neste dataset o separador é ponto-e-vírgula.
#
# Esta tarefa é dividida em to-dos, isto é, pequenas atividades que devem ser cumpridas para que o objetivo geral seja alcançado. A cada to-do está associada uma célula do Jupyter Notebook, que deve ser preenchida com código Python atendendo ao que se pede.
# ***

# %%
##Equipe: Lucas Pereira Reis e Iêsa Braga Lobato

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### To-Do 1
#
# 1. Abra o dataset com o pandas;
# 2. Elimine os exemplos em que há dados faltantes (NaN - Not a Number;
# 3. Exclua a coluna name (não será necessária)
# 3. Imprima o dataset.

# %%
df = pd.read_csv('autompg.csv',delimiter=';')

# %%
df.dropna(inplace=True)

# %%
df.drop(['name'],axis=1,inplace=True)

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0        8.0         307.0       130.0  3504.0          12.0
# 1    15.0        8.0         350.0       165.0  3693.0          11.5
# 2    18.0        8.0         318.0       150.0  3436.0          11.0
# 3    16.0        8.0         304.0       150.0  3433.0          12.0
# 4    17.0        8.0         302.0       140.0  3449.0          10.5
# 5    15.0        8.0         429.0       198.0  4341.0          10.0
# 6    14.0        8.0         454.0       220.0  4354.0           9.0
# 7    14.0        8.0         440.0       215.0  4312.0           8.5
# 8    14.0        8.0         455.0       225.0  4425.0          10.0
# 9    15.0        8.0         390.0       190.0  3850.0           8.5
# 15   15.0        8.0         383.0       170.0  3563.0          10.0
# 16   14.0        8.0         340.0       160.0  3609.0           8.0
# 18   15.0        8.0         400.0       150.0  3761.0           9.5
# 19   14.0        8.0         455.0       225.0  3086.0          10.0
# 20   24.0        4.0         113.0        95.0  2372.0          15.0
# 21   22.0        6.0         198.0        95.0  2833.0          15.5
# 22   18.0        6.0         199.0        97.0  2774.0          15.5
# 23   21.0        6.0         200.0        85.0  2587.0          16.0
# 24   27.0        4.0          97.0        88.0  2130.0          14.5
# 25   26.0        4.0          97.0        46.0  1835.0          20.5
# 26   25.0        4.0         110.0        87.0  2672.0          17.5
# 27   24.0        4.0         107.0        90.0  2430.0          14.5
# 28   25.0        4.0         104.0        95.0  2375.0          17.5
# 29   26.0        4.0         121.0       113.0  2234.0          12.5
# 30   21.0        6.0         199.0        90.0  2648.0          15.0
# 31   10.0        8.0         360.0       215.0  4615.0          14.0
# 32   10.0        8.0         307.0       200.0  4376.0          15.0
# 381       82.0     1.0
# 383       82.0     2.0
# 384       82.0     3.0
# 385       82.0     3.0
# 386       82.0     1.0
# 387       82.0     1.0
# 388       82.0     3.0
# 389       82.0     3.0
# 390       82.0     3.0
# 391       82.0     3.0
# 392       82.0     3.0
# 393       82.0     3.0
# 394       82.0     1.0
# 395       82.0     1.0
# 396       82.0     1.0
# 397       82.0     1.0
# 398       82.0     3.0
# 399       82.0     1.0
# 400       82.0     1.0
# 401       82.0     1.0
# 402       82.0     2.0
# 403       82.0     1.0
# 404       82.0     1.0
# 405       82.0     1.0
#
# [392 rows x 8 columns]

# %% [markdown]
# ### To-Do 2
#
# Vamos agora construir um modelo de regressão linear para prever o atributo alvo 'mpg' em questão.
#
# 1. Separe o dataset de maneira análoga ao indicando na parte 1.1 deste teste, considerando agora a partição 60/40 para treinamento e teste.
# 2. Complete o código para treinamento do modelo, fornecendo atributos preditores e atributo alvo do conjunto de treinamento

# %%
y_mpg = np.array(df.mpg)
df
df.drop(['mpg'],axis=1,inplace=True)

# %%
df_train, df_test, ympg_train, ympg_test = train_test_split(df,y_mpg, test_size=0.40)

# %%
from sklearn import linear_model

regr = linear_model.LinearRegression()
regr.fit(df_train, ympg_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# ### To-Do 3
#
# Preveja os resultados para o conjunto de testes, usando o modelo em questão.

# %%
previsao_regr = regr.predict(df_test)

# %% [markdown]
# ### To-Do 4
#
# Calcule o RMSE (root-mean-square error) para as previsões realizadas. Não utilize bibliotecas prontas para esta tarefa.

# %%
sumt = 0
#previsto - real
for i in range(len(previsao_regr)):
    sumt += ((previsao_regr[i] - ympg_test[i])**2)
rmse = (sumt/len(previsao_regr))**0.5
rmse
# Out:
# 3.3823863764636979

# %% [markdown]
# ### To-Do 5
#
# Calcule o R-Squared para os dados. De maneira análoga, não utilize bibliotecas prontas para esta tarefa.

# %%
s1 = 0
#previsto - real
for i in range(len(previsao_regr)):
    s1 += ((ympg_test[i] - previsao_regr[i])**2)
cont = 0
for i in range(len(ympg_test)):
    cont += ympg_test[i]
media = cont/len(ympg_test)
s2 = 0
for i in range(len(ympg_test)):
    s2 += (ympg_test[i] - media)**2
r_square = 1-(s1/s2)
r_square
# Out:
# 0.81172430727581268

# %% [markdown]
# ### To-Do 7
#
# Em um mesmo gráfico, plote:
# 1. Uma reta-0
# 2. Os resíduos, sob a forma de pontos com as coordenadas: (mpg,residuo correspondente)
# 3. Nomeie apropriadamente os eixos no gráfico

# %%
df = pd.DataFrame()
aux = pd.Series(ympg_test, name = 'ympg')
df['observado'] = aux
df['previsto'] = previsao_regr
sns.lmplot(x = 'observado', y = 'previsto', data = df)
plt.show()

# %% [markdown]
# ### To-Do 8
#
# Utilizando argumentos textuais, justifique a qualidade do modelo apresentado para o problema em questão.

# %% [markdown]
# O modelo mostrou-se eficiente pois obteve valor de 81.17% na métrica R-Square e variação de apenas 3,38 na métrica RSME, que é um valor irrelevante quando comparado ao total.
